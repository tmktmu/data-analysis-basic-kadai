# %%
import numpy as np

# %%
#行列Aの作成
A=[[0,1],[2,3],[4,5]]
A
# Out:
# [[0, 1], [2, 3], [4, 5]]

# %%
#行列Bの作成
B=[[0,1,2,3],[4,5,6,7]]
B
# Out:
# [[0, 1, 2, 3], [4, 5, 6, 7]]

# %%
#行列の積の計算
C=np.dot(A,B)
C
# Out:
# array([[ 4,  5,  6,  7],
#        [12, 17, 22, 27],
#        [20, 29, 38, 47]])

# %%
np.max(C)
# Out:
# np.int64(47)
